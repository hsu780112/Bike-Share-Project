# %% [markdown]
# # Modeling - Feature Engineering - Bike Share System in the SF Bay Area

# %% [markdown]
# Author: Owen Hsu

# %% [markdown]
# ## Table of content

# %% [markdown]
# 1. Loading and Setup
# 2. Assessment
# 3. Spliting Training Set into Training and Validation Sets
# 4. Baseline Modeling
#    * Logistic Regression
#    * Decision Tree
#    * Random Forest
#    * K-Nearest Neighbors (KNN)
#    * Support Vector Machine (SVM)
#    * XGBoost

# %% [markdown]
# ## Loading and Setup

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import OneHotEncoder, StandardScaler 
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, cross_val_predict, RandomizedSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, precision_score, recall_score, f1_score, roc_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE
import time
import pickle
import os
# Filter warnings
from warnings import filterwarnings
filterwarnings('ignore')
# Out:
# /Users/chih-kanghsu/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# Load the datasets
train_df = pd.read_parquet('data/train_dataset.parquet')
test_df = pd.read_parquet('data/test_dataset.parquet')

# %% [markdown]
# ## Assessment

# %%
# Set display options to show all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# #### Train Data

# %%
# Print the shape of the train data
train_df.shape
# Out:
# (11831433, 19)

# %%
# Look at the first 5 rows of the train dataset
train_df.head()
# Out:
#    station_id  bikes_available  dock_count  mean_dew_point_f  mean_humidity  \
# 0   -1.375345        -0.789945   -0.667162         -0.099799      -0.428081
# 1    1.125367         0.647661    0.336991          0.776477       0.410568
# 2    1.125367         1.366463    0.336991         -1.122121       0.410568
# 3    0.083403         0.168459   -0.667162         -0.537937       1.715132
# 4    0.125082        -0.310743   -0.667162          0.776477       1.062850
#
#    mean_sea_level_pressure_inches  mean_visibility_miles  mean_wind_speed_mph  \
# 0                        0.388370               0.306077            -1.406683
# 1                       -0.153740               0.306077             1.015281
# 2                        2.014700              -0.455251            -0.195701
# 3                        0.543259              -2.739235            -1.103938
# 4                       -0.463517               0.306077             0.712536
#
#    precipitation_inches  cloud_cover  zip_code   holiday  \
# 0             -0.436337    -1.014580  1.820021 -0.168116
# 1             -0.436337     0.779536 -0.548136 -0.168116
# 2             -0.436337    -0.566051 -0.548136 -0.168116
# 3             -0.436337     0.779536 -0.548136 -0.168116
# 4             -0.436337     0.331007 -0.548136 -0.168116
#
#    is_weekend_or_holiday      year     month       day      hour    minute  \
# 0               1.482137  1.427242 -1.310568 -0.195224  1.228122 -1.303354
# 1               1.482137 -0.700652  0.428313  0.145410  0.216731 -0.434267
# 2              -0.674701  1.427242 -1.600382  0.713132 -1.372598 -0.723963
# 3               1.482137  1.427242 -1.600382 -0.535857  0.939153 -0.434267
# 4              -0.674701 -0.700652  1.007940 -0.762946  0.650184  1.593602
#
#    usage_rate_category
# 0                  2.0
# 1                  2.0
# 2                  1.0
# 3                  2.0
# 4                  2.0

# %%
# Verify the train dataset
train_df.sample(10)
# Out:
#           station_id  bikes_available  dock_count  mean_dew_point_f  \
# 1942511     0.750260         1.845665    2.345298          0.484385
# 6175911    -0.333382        -0.071142   -1.671316          1.360661
# 4300025    -1.583738        -0.550344    0.336991         -0.391891
# 11180396    1.625510        -1.269147   -0.667162          1.214615
# 11256701    1.708867        -1.269147   -0.667162          0.922523
# 10168407   -1.125274        -1.269147   -0.667162         -0.830029
# 11055743    0.750260        -0.643562    2.345298          0.776477
# 764696      0.583546        -0.550344   -0.667162         -0.391891
# 8217357     0.291796         2.725167    1.341144          0.338339
# 3705682     1.250403        -1.269147   -0.667162          0.484385
#
#           mean_humidity  mean_sea_level_pressure_inches  \
# 1942511        0.503751                       -0.773294
# 6175911        0.131018                       -1.392848
# 4300025       -1.173546                        0.853036
# 11180396       0.410568                       -0.386072
# 11256701      -0.334897                       -0.618405
# 10168407       0.503751                        0.310926
# 11055743       0.224201                       -0.308628
# 764696         1.342399                        0.930480
# 8217357       -1.266729                       -0.773294
# 3705682        1.156033                       -0.773294
#
#           mean_visibility_miles  mean_wind_speed_mph  precipitation_inches  \
# 1942511                0.306077            -0.195701             -0.436337
# 6175911                0.306077             0.712536             -0.436337
# 4300025                0.306077            -0.195701             -0.436337
# 11180396               0.306077             1.318027             -0.436337
# 11256701               0.306077             0.107045             -0.436337
# 10168407               0.306077            -0.498447              2.291809
# 11055743               0.306077             0.712536              2.291809
# 764696                -1.216579            -1.103938             -0.436337
# 8217357                0.306077            -0.498447             -0.436337
# 3705682                0.306077            -0.801192             -0.436337
#
#           cloud_cover  zip_code   holiday  is_weekend_or_holiday      year  \
# 1942511      0.779536 -0.548136 -0.168116              -0.674701 -0.700652
# 6175911     -0.117522 -0.091454 -0.168116              -0.674701 -0.700652
# 4300025     -0.566051  1.820021 -0.168116               1.482137  1.427242
# 11180396     1.228065 -0.548136 -0.168116              -0.674701 -0.700652
# 11256701    -1.014580  1.820021 -0.168116              -0.674701 -0.700652
# 10168407     0.779536  1.820021 -0.168116               1.482137 -0.700652
# 11055743     1.228065 -0.548136 -0.168116               1.482137 -0.700652
# 764696       0.331007 -0.548136 -0.168116              -0.674701  1.427242
# 8217357     -1.014580 -0.548136 -0.168116               1.482137 -0.700652
# 3705682     -1.014580 -0.548136 -0.168116               1.482137 -0.700652
#
#              month       day      hour    minute  usage_rate_category
# 1942511   1.007940  1.621488  0.650184  0.145124                  2.0
# 6175911   0.428313  0.372499 -0.740320 -1.412307                  1.0
# 4300025  -1.020755  1.394399  0.794669  1.303906                  2.0
# 11180396  0.138499 -0.081679 -1.071216  1.279017                  3.0
# 11256701  0.138499  0.940221  0.072246 -1.485883                  3.0
# 10168407  1.587567 -0.195224 -0.778723 -0.434267                  3.0
# 11055743  0.428313 -0.649401  0.272943 -0.434267                  3.0
# 764696   -1.310568 -1.557757 -1.228114  1.014211                  2.0
# 8217357   1.007940 -1.217124  0.986733 -0.434267                  1.0
# 3705682   1.297754 -0.762946  0.650184 -0.144572                  3.0

# %%
# Get a quick overview of dataset variables
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11831433 entries, 0 to 11831432
# Data columns (total 19 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   station_id                      float64
#  1   bikes_available                 float64
#  2   dock_count                      float64
#  3   mean_dew_point_f                float64
#  4   mean_humidity                   float64
#  5   mean_sea_level_pressure_inches  float64
#  6   mean_visibility_miles           float64
#  7   mean_wind_speed_mph             float64
#  8   precipitation_inches            float64
#  9   cloud_cover                     float64
#  10  zip_code                        float64
#  11  holiday                         float64
#  12  is_weekend_or_holiday           float64
#  13  year                            float64
#  14  month                           float64
#  15  day                             float64
#  16  hour                            float64
#  17  minute                          float64
#  18  usage_rate_category             float64
# dtypes: float64(19)
# memory usage: 1.7 GB

# %%
# Get a statistical summary of the dataset
train_df.describe()
# Out:
#          station_id  bikes_available    dock_count  mean_dew_point_f  \
# count  1.183143e+07     1.183143e+07  1.183143e+07      1.183143e+07
# mean   8.728673e-02     1.407248e-01  4.538602e-02      6.191241e-04
# std    9.863458e-01     1.296435e+00  1.019171e+00      9.762055e-01
# min   -1.708774e+00    -1.987950e+00 -1.671316e+00     -5.357456e+00
# 25%   -6.668103e-01    -1.029546e+00 -6.671623e-01     -5.379373e-01
# 50%    2.084391e-01    -7.114224e-02 -6.671623e-01      4.624675e-02
# 75%    9.586529e-01     8.872615e-01  3.369910e-01      7.764768e-01
# max    1.708867e+00     4.481276e+00  2.345298e+00      2.236937e+00
#
#        mean_humidity  mean_sea_level_pressure_inches  mean_visibility_miles  \
# count   1.183143e+07                    1.183143e+07           1.183143e+07
# mean    2.849037e-02                    1.324620e-02          -3.006021e-02
# std     9.795221e-01                    1.004863e+00           9.955864e-01
# min    -4.155406e+00                   -3.019177e+00          -4.261891e+00
# 25%    -4.280805e-01                   -6.958494e-01           3.060765e-01
# 50%     1.310183e-01                   -1.537396e-01           3.060765e-01
# 75%     5.969340e-01                    7.755915e-01           3.060765e-01
# max     2.553780e+00                    3.021475e+00           7.919356e+00
#
#        mean_wind_speed_mph  precipitation_inches   cloud_cover      zip_code  \
# count         1.183143e+07          1.183143e+07  1.183143e+07  1.183143e+07
# mean          3.542641e-02          2.947676e-02  4.194595e-02 -5.911484e-02
# std           1.016661e+00          1.026560e+00  1.002546e+00  9.581599e-01
# min          -2.012174e+00         -4.363365e-01 -1.463109e+00 -7.035020e-01
# 25%          -8.011921e-01         -4.363365e-01 -1.014580e+00 -5.481358e-01
# 50%          -1.957009e-01         -4.363365e-01 -1.175220e-01 -5.481358e-01
# 75%           7.125358e-01         -4.363365e-01  7.795363e-01 -9.145356e-02
# max           4.950974e+00          2.291809e+00  2.125124e+00  1.820021e+00
#
#             holiday  is_weekend_or_holiday          year         month  \
# count  1.183143e+07           1.183143e+07  1.183143e+07  1.183143e+07
# mean  -1.487793e-02          -3.440722e-02  3.752040e-02 -5.401867e-03
# std    9.559194e-01           9.854109e-01  1.012845e+00  1.012741e+00
# min   -1.681160e-01          -6.747013e-01 -7.006522e-01 -1.600382e+00
# 25%   -1.681160e-01          -6.747013e-01 -7.006522e-01 -1.020755e+00
# 50%   -1.681160e-01          -6.747013e-01 -7.006522e-01  1.384995e-01
# 75%   -1.681160e-01           1.482137e+00  1.427242e+00  1.007940e+00
# max    5.948273e+00           1.482137e+00  1.427242e+00  1.587567e+00
#
#                 day          hour        minute  usage_rate_category
# count  1.183143e+07  1.183143e+07  1.183143e+07         1.183143e+07
# mean   1.451822e-03 -8.437618e-03  3.482028e-04         2.000000e+00
# std    9.917044e-01  1.006911e+00  9.949198e-01         8.164966e-01
# min   -1.671302e+00 -1.661567e+00 -1.593049e+00         1.000000e+00
# 25%   -8.764904e-01 -9.391449e-01 -8.729036e-01         1.000000e+00
# 50%    3.186537e-02 -6.895456e-02  8.465121e-03         2.000000e+00
# 75%    8.266767e-01  9.187592e-01  8.672886e-01         3.000000e+00
# max    1.735032e+00  1.661576e+00  1.593602e+00         3.000000e+00

# %% [markdown]
# #### Test Data

# %%
# Print the shape of the test data
test_df.shape
# Out:
# (1467439, 19)

# %%
# Look at the first 5 rows of the test dataset
test_df.head()
# Out:
#    station_id  bikes_available  dock_count  mean_dew_point_f  mean_humidity  \
# 0    0.750260        -1.029546    2.345298          0.922523       0.596934
# 1   -0.416739        -0.071142   -0.667162          0.776477       1.249216
# 2   -0.375060        -1.269147    1.341144          0.192293      -0.800813
# 3    1.333760        -0.550344    0.336991          0.922523       0.317385
# 4   -1.667095        -0.550344   -0.667162         -0.537937      -0.893996
#
#    mean_sea_level_pressure_inches  mean_visibility_miles  mean_wind_speed_mph  \
# 0                        0.001149               0.306077            -0.801192
# 1                       -0.540961              -0.455251             0.107045
# 2                        0.853036               0.306077             0.409790
# 3                       -0.540961               0.306077             0.712536
# 4                       -0.463517               0.306077             0.712536
#
#    precipitation_inches  cloud_cover  zip_code   holiday  \
# 0              2.291809     0.779536 -0.548136 -0.168116
# 1              2.291809    -0.117522 -0.703502 -0.168116
# 2             -0.436337    -0.117522 -0.091454 -0.168116
# 3             -0.436337     0.779536 -0.548136 -0.168116
# 4             -0.436337     0.779536  1.820021 -0.168116
#
#    is_weekend_or_holiday      year     month       day      hour    minute  \
# 0              -0.674701 -0.700652  1.007940  0.826677 -1.083629  0.724515
# 1              -0.674701 -0.700652  1.587567 -0.649401 -1.661567 -0.434267
# 2               1.482137  1.427242 -1.020755  1.394399 -0.216723 -1.303354
# 3              -0.674701 -0.700652  0.138499  1.735032  1.661576  0.724515
# 4              -0.674701 -0.700652 -0.441128  0.372499 -0.361207  0.145124
#
#    usage_rate_category
# 0                  3.0
# 1                  2.0
# 2                  3.0
# 3                  2.0
# 4                  2.0

# %%
# Verify the test dataset
test_df.sample(10)
# Out:
#          station_id  bikes_available  dock_count  mean_dew_point_f  \
# 1028328   -0.500096         0.168459   -0.667162          1.068569
# 560458    -0.291703        -0.071142   -0.667162          0.338339
# 908766     1.375438        -1.269147    0.336991          0.776477
# 632807     1.000331         1.126862    2.345298         -0.537937
# 1137048    0.791939        -0.310743    0.336991         -0.976075
# 864556    -1.208631         0.647661    0.336991          0.922523
# 494204     1.083688         2.564468    1.341144         -0.245845
# 756455     0.333475         1.126862    0.336991         -0.099799
# 1309375   -1.500381         1.606064   -0.667162         -0.391891
# 1311516    1.292081         2.564468    1.341144         -0.537937
#
#          mean_humidity  mean_sea_level_pressure_inches  mean_visibility_miles  \
# 1028328      -0.241714                       -0.231184               0.306077
# 560458       -2.384926                        0.310926               0.170572
# 908766        0.969667                       -0.231184               0.306077
# 632807        0.410568                        1.859811              -0.455251
# 1137048       0.037835                       -0.695849              -0.455251
# 864556        1.715132                        2.014700               0.306077
# 494204        0.783300                        0.388370              -1.216579
# 756455       -0.055348                        1.937255               0.306077
# 1309375      -1.173546                        0.853036               0.306077
# 1311516       1.715132                        1.550034              -1.977907
#
#          mean_wind_speed_mph  precipitation_inches  cloud_cover  zip_code  \
# 1028328             0.712536             -0.436337    -1.463109 -0.703502
# 560458             -0.195701             -0.436337     0.331007 -0.091454
# 908766              1.923518              2.291809     1.676595 -0.548136
# 632807             -1.103938             -0.436337    -0.566051 -0.548136
# 1137048             1.318027              2.291809     0.779536 -0.548136
# 864556             -0.195701              2.291809     1.676595  1.820021
# 494204              0.107045             -0.436337    -0.117522 -0.548136
# 756455             -0.801192             -0.436337    -0.566051 -0.548136
# 1309375            -0.195701             -0.436337    -0.566051  1.820021
# 1311516            -1.406683             -0.436337    -0.117522 -0.548136
#
#           holiday  is_weekend_or_holiday      year     month       day  \
# 1028328 -0.168116              -0.674701 -0.700652  0.138499  0.145410
# 560458  -0.168116              -0.674701 -0.700652 -0.441128 -1.671302
# 908766  -0.168116              -0.674701 -0.700652 -0.151314  1.053766
# 632807  -0.168116              -0.674701 -0.700652  1.297754  1.167310
# 1137048 -0.168116               1.482137  1.427242 -0.730941 -1.217124
# 864556  -0.168116               1.482137 -0.700652  1.587567  0.599588
# 494204  -0.168116               1.482137  1.427242 -1.020755 -0.876490
# 756455  -0.168116              -0.674701 -0.700652  1.297754 -1.330668
# 1309375 -0.168116               1.482137  1.427242 -1.020755  1.394399
# 1311516 -0.168116              -0.674701  1.427242 -1.600382 -0.422313
#
#              hour    minute  usage_rate_category
# 1028328  0.072246  0.145124                  2.0
# 560458   0.939153 -0.723963                  2.0
# 908766   1.228122 -1.593049                  3.0
# 632807  -0.216723  1.593602                  2.0
# 1137048  1.517091  1.014211                  2.0
# 864556  -0.216723  1.014211                  2.0
# 494204  -0.650176  1.303906                  1.0
# 756455  -1.517083  1.593602                  2.0
# 1309375 -1.083629  1.593602                  1.0
# 1311516  1.372607  0.434820                  1.0

# %%
# Get a quick overview of dataset variables
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1467439 entries, 0 to 1467438
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   station_id                      1467439 non-null  float64
#  1   bikes_available                 1467439 non-null  float64
#  2   dock_count                      1467439 non-null  float64
#  3   mean_dew_point_f                1467439 non-null  float64
#  4   mean_humidity                   1467439 non-null  float64
#  5   mean_sea_level_pressure_inches  1467439 non-null  float64
#  6   mean_visibility_miles           1467439 non-null  float64
#  7   mean_wind_speed_mph             1467439 non-null  float64
#  8   precipitation_inches            1467439 non-null  float64
#  9   cloud_cover                     1467439 non-null  float64
#  10  zip_code                        1467439 non-null  float64
#  11  holiday                         1467439 non-null  float64
#  12  is_weekend_or_holiday           1467439 non-null  float64
#  13  year                            1467439 non-null  float64
#  14  month                           1467439 non-null  float64
#  15  day                             1467439 non-null  float64
#  16  hour                            1467439 non-null  float64
#  17  minute                          1467439 non-null  float64
#  18  usage_rate_category             1467439 non-null  float64
# dtypes: float64(19)
# memory usage: 212.7 MB

# %%
# Get a statistical summary of the dataset
test_df.describe()
# Out:
#          station_id  bikes_available    dock_count  mean_dew_point_f  \
# count  1.467439e+06     1.467439e+06  1.467439e+06      1.467439e+06
# mean  -1.110399e-03    -7.235799e-04 -9.088503e-04     -2.253745e-04
# std    1.000178e+00     9.994657e-01  9.984484e-01      1.001204e+00
# min   -1.708774e+00    -1.987950e+00 -1.671316e+00     -5.357456e+00
# 25%   -7.918459e-01    -7.899451e-01 -6.671623e-01     -5.379373e-01
# 50%   -4.163215e-02    -7.114224e-02 -6.671623e-01      4.624675e-02
# 75%    8.752958e-01     6.476606e-01  3.369910e-01      7.764768e-01
# max    1.708867e+00     4.481276e+00  2.345298e+00      2.236937e+00
#
#        mean_humidity  mean_sea_level_pressure_inches  mean_visibility_miles  \
# count   1.467439e+06                    1.467439e+06           1.467439e+06
# mean    1.104140e-03                    8.589169e-05           6.632739e-04
# std     1.000368e+00                    1.000515e+00           1.000051e+00
# min    -4.155406e+00                   -3.019177e+00          -4.261891e+00
# 25%    -5.212637e-01                   -6.958494e-01           3.060765e-01
# 50%     3.783516e-02                   -1.537396e-01           3.060765e-01
# 75%     5.969340e-01                    6.981473e-01           3.060765e-01
# max     2.553780e+00                    3.021475e+00           7.919356e+00
#
#        mean_wind_speed_mph  precipitation_inches   cloud_cover      zip_code  \
# count         1.467439e+06          1.467439e+06  1.467439e+06  1.467439e+06
# mean          1.124246e-03          5.678869e-04  2.040834e-03  2.704992e-04
# std           9.999969e-01          1.000527e+00  9.995878e-01  1.000361e+00
# min          -2.012174e+00         -4.363365e-01 -1.463109e+00 -7.035020e-01
# 25%          -8.011921e-01         -4.363365e-01 -1.014580e+00 -5.481358e-01
# 50%          -1.957009e-01         -4.363365e-01 -1.175220e-01 -5.481358e-01
# 75%           7.125358e-01         -4.363365e-01  7.795363e-01 -9.145356e-02
# max           4.950974e+00          2.291809e+00  2.125124e+00  1.820021e+00
#
#             holiday  is_weekend_or_holiday          year         month  \
# count  1.467439e+06           1.467439e+06  1.467439e+06  1.467439e+06
# mean  -3.428524e-04           2.534252e-04  1.767896e-04 -3.142766e-05
# std    9.990089e-01           1.000103e+00  1.000065e+00  9.997948e-01
# min   -1.681160e-01          -6.747013e-01 -7.006522e-01 -1.600382e+00
# 25%   -1.681160e-01          -6.747013e-01 -7.006522e-01 -7.309411e-01
# 50%   -1.681160e-01          -6.747013e-01 -7.006522e-01  1.384995e-01
# 75%   -1.681160e-01           1.482137e+00  1.427242e+00  1.007940e+00
# max    5.948273e+00           1.482137e+00  1.427242e+00  1.587567e+00
#
#                 day          hour        minute  usage_rate_category
# count  1.467439e+06  1.467439e+06  1.467439e+06         1.467439e+06
# mean  -8.078574e-04  2.174742e-05  1.212700e-03         2.071246e+00
# std    9.996474e-01  9.993584e-01  1.000312e+00         5.689108e-01
# min   -1.671302e+00 -1.661567e+00 -1.593049e+00         1.000000e+00
# 25%   -8.764904e-01 -7.946604e-01 -7.239626e-01         2.000000e+00
# 50%    3.186537e-02  7.224641e-02  1.451240e-01         2.000000e+00
# 75%    8.266767e-01  7.946688e-01  1.014211e+00         2.000000e+00
# max    1.735032e+00  1.661576e+00  1.593602e+00         3.000000e+00

# %% [markdown]
# ## Spliting Training Set into Training and Validation Sets

# %%
# Separate features and target variable from the train set
X_train_full = train_df.drop(columns=['usage_rate_category'])
y_train_full = train_df['usage_rate_category']

# Split the training dataset into training and validation subsets
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=42)

# Separate features and target variable from the test set
X_test = test_df.drop(columns=['usage_rate_category'])
y_test = test_df['usage_rate_category']

# Check the shapes of the datasets
print(f'Shape of test set: {X_train.shape}')
print(f'Shape of validation set: {X_val.shape}')
print(f'Shape of train set: {X_test.shape}')
# Out:
# Shape of test set: (9465146, 18)
# Shape of validation set: (2366287, 18)
# Shape of train set: (1467439, 18)

# %% [markdown]
# ## Baseline Modeling

# %% [markdown]
# #### Logistic Regression

# %% [markdown]
# Let's fit a logistic regression model on the data and analyze the test and train accuracy.

# %%
# Initialize the model
logreg = LogisticRegression(random_state=42)

# Fitting a model
logreg.fit(X_train, y_train)

# Get class predictions
y_pred_logreg = logreg.predict(X_val)

# Training and test score
print('Logistic Regression')
print(f"Train score: {logreg.score(X_train, y_train)}")
print(f"Test score: {logreg.score(X_val, y_val)}")

# Generate confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_val, y_pred_logreg))

# Classification report 
print("\nClassification Report:")
print(classification_report(y_val, y_pred_logreg))
# Out:
# Logistic Regression
# Train score: 0.9877043629332289
# Test score: 0.9876071668398635
#
# Confusion Matrix:
# [[781460   6559    250]
#  [  5808 773991   9100]
#  [     0   7608 781511]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.99      0.99      0.99    788269
#          2.0       0.98      0.98      0.98    788899
#          3.0       0.99      0.99      0.99    789119
#
#     accuracy                           0.99   2366287
#    macro avg       0.99      0.99      0.99   2366287
# weighted avg       0.99      0.99      0.99   2366287

# %% [markdown]
# Test

# %%
X_train_2 = X_train.copy()
X_train_2 = X_train_2.drop(columns=['bikes_available'])
X_train_2.head()
# Out:
#          station_id  dock_count  mean_dew_point_f  mean_humidity  \
# 3814887    1.125367    0.336991         -0.099799      -0.800813
# 8633336   -0.166668    0.336991          0.046247       0.131018
# 4123750   -0.333382   -1.671316          0.630431      -1.080363
# 3925458    0.166761    0.336991          0.192293      -0.334897
# 2080432   -0.416739   -0.667162         -0.830029       0.503751
#
#          mean_sea_level_pressure_inches  mean_visibility_miles  \
# 3814887                        0.310926               0.306077
# 8633336                        0.543259               0.306077
# 4123750                       -0.463517               7.919356
# 3925458                        0.310926               0.306077
# 2080432                        0.388370               0.306077
#
#          mean_wind_speed_mph  precipitation_inches  cloud_cover  zip_code  \
# 3814887             0.107045             -0.436337    -1.014580 -0.548136
# 8633336            -0.195701             -0.436337    -1.014580 -0.548136
# 4123750             0.107045             -0.436337     0.331007 -0.091454
# 3925458             1.620772             -0.436337     0.779536 -0.548136
# 2080432            -0.801192              2.291809    -0.117522 -0.703502
#
#           holiday  is_weekend_or_holiday      year     month       day  \
# 3814887 -0.168116              -0.674701 -0.700652  1.007940  0.599588
# 8633336 -0.168116              -0.674701 -0.700652  1.007940  1.394399
# 4123750 -0.168116              -0.674701 -0.700652 -0.151314  0.486043
# 3925458 -0.168116              -0.674701 -0.700652 -0.441128  0.031865
# 2080432 -0.168116               1.482137 -0.700652  1.587567 -0.195224
#
#              hour    minute
# 3814887  0.361215  0.434820
# 8633336  0.908514 -1.303354
# 4123750 -0.361207  1.593602
# 3925458  0.939153  1.593602
# 2080432  0.794669  1.014211

# %%
X_val_2 = X_val.copy()
X_val_2 = X_val_2.drop(columns=['bikes_available'])
X_val_2.head()
# Out:
#           station_id  dock_count  mean_dew_point_f  mean_humidity  \
# 11686255    0.750260    2.345298         -0.391891      -1.266729
# 2200011    -0.791846   -0.667162          0.776477       0.410568
# 549345      0.750260    2.345298          0.776477       0.410568
# 3255008    -0.708489   -0.667162         -0.391891       1.621949
# 6006242    -0.208346   -0.667162          1.506707      -0.428081
#
#           mean_sea_level_pressure_inches  mean_visibility_miles  \
# 11686255                       -0.618405               0.306077
# 2200011                        -0.850738               0.306077
# 549345                         -1.005626              -0.455251
# 3255008                         0.465814              -0.455251
# 6006242                        -1.857513               0.306077
#
#           mean_wind_speed_mph  precipitation_inches  cloud_cover  zip_code  \
# 11686255             0.409790             -0.436337    -1.014580 -0.548136
# 2200011             -0.801192             -0.436337    -0.117522 -0.651713
# 549345              -0.498447             -0.436337    -1.014580 -0.548136
# 3255008             -1.709429              2.291809     1.228065 -0.651713
# 6006242              0.107045             -0.436337    -0.566051 -0.091454
#
#            holiday  is_weekend_or_holiday      year     month       day  \
# 11686255 -0.168116              -0.674701 -0.700652 -0.441128  1.507944
# 2200011  -0.168116               1.482137 -0.700652  0.428313  0.826677
# 549345   -0.168116              -0.674701 -0.700652  1.007940 -0.876490
# 3255008  -0.168116               1.482137 -0.700652  1.587567 -0.195224
# 6006242  -0.168116              -0.674701 -0.700652  0.718126  0.145410
#
#               hour    minute
# 11686255  1.083638  0.818771
# 2200011  -1.372598 -1.593049
# 549345   -0.216723 -0.434267
# 3255008  -0.072238  0.145124
# 6006242   0.505822  0.434576

# %%
# Initialize the model
logreg = LogisticRegression(random_state=42)

# Fitting a model
logreg.fit(X_train_2, y_train)

# Get class predictions
y_pred_logreg = logreg.predict(X_val_2)

# Training and test score
print('Logistic Regression')
print(f"Train score: {logreg.score(X_train_2, y_train)}")
print(f"Test score: {logreg.score(X_val_2, y_val)}")

# Generate confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_val, y_pred_logreg))

# Classification report 
print("\nClassification Report:")
print(classification_report(y_val, y_pred_logreg))
# Out:
# Logistic Regression
# Train score: 0.40004676103252923
# Test score: 0.4007438658117126
#
# Confusion Matrix:
# [[292757 266410 229102]
#  [216754 381596 190549]
#  [251265 263932 273922]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.38      0.37      0.38    788269
#          2.0       0.42      0.48      0.45    788899
#          3.0       0.39      0.35      0.37    789119
#
#     accuracy                           0.40   2366287
#    macro avg       0.40      0.40      0.40   2366287
# weighted avg       0.40      0.40      0.40   2366287

# %% [markdown]
# #### Decision Tree

# %%
# Initialize the model
dt_model = DecisionTreeClassifier(random_state=42)

# Fitting a model
dt_model.fit(X_train, y_train);

# Get class predictions
y_pred_dt_model = dt_model.predict(X_val)

# Evaluate its classification accuracy
print('Decision Tree:')
print(f'Train score: {dt_model.score(X_train, y_train)}')
print(f'Test score: {dt_model.score(X_val, y_val)}')

# Generate confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_val, y_pred_dt_model))

# Classification report 
print("\nClassification Report:")
print(classification_report(y_val, y_pred_dt_model))
# Out:
# Decision Tree:
# Train score: 1.0
# Test score: 0.9996450134746968
#
# Confusion Matrix:
# [[788098    168      3]
#  [   207 788466    226]
#  [     3    233 788883]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       1.00      1.00      1.00    788269
#          2.0       1.00      1.00      1.00    788899
#          3.0       1.00      1.00      1.00    789119
#
#     accuracy                           1.00   2366287
#    macro avg       1.00      1.00      1.00   2366287
# weighted avg       1.00      1.00      1.00   2366287

# %% [markdown]
# Test

# %%
# Initialize the model
dt_model = DecisionTreeClassifier(random_state=42)

# Fitting a model
dt_model.fit(X_train_2, y_train);

# Get class predictions
y_pred_dt_model = dt_model.predict(X_val_2)

# Evaluate its classification accuracy
print('Decision Tree:')
print(f'Train score: {dt_model.score(X_train_2, y_train)}')
print(f'Test score: {dt_model.score(X_val_2, y_val)}')

# Generate confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_val, y_pred_dt_model))

# Classification report 
print("\nClassification Report:")
print(classification_report(y_val, y_pred_dt_model))
# Out:
# Decision Tree:
# Train score: 1.0
# Test score: 0.9789252106781637
#
# Confusion Matrix:
# [[773904   8150   6215]
#  [  8644 769758  10497]
#  [  6522   9841 772756]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          1.0       0.98      0.98      0.98    788269
#          2.0       0.98      0.98      0.98    788899
#          3.0       0.98      0.98      0.98    789119
#
#     accuracy                           0.98   2366287
#    macro avg       0.98      0.98      0.98   2366287
# weighted avg       0.98      0.98      0.98   2366287

# %% [markdown]
# #### Random Forest

# %%
# Initialize the model
random_forest_model = RandomForestClassifier(random_state=42)

# Fitting a model
random_forest_model.fit(X_train, y_train)

# Evaluate its classification accuracy
print(f'Train score: {random_forest_model.score(X_train, y_train)}')
print(f'Test score: {random_forest_model.score(X_val, y_val)}')

# Get class predictions
y_pred_random_forest_model = random_forest_model.predict(X_val)

# Generate confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_val, y_pred_random_forest_model))

# Classification report 
print("\nClassification Report:")
print(classification_report(y_val, y_pred_random_forest_model))

# %% [markdown]
# #### K-Nearest Neighbors (KNN)

# %%
# Initialize the model
KNN_model = KNeighborsClassifier(n_neighbors=3)

# Fitting a model
KNN_model.fit(X_train, y_train)

# Evaluate its classification accuracy
print(f'Train score: {KNN_model.score(X_train, y_train)}')
print(f'Test score: {KNN_model.score(X_val, y_val)}')

# Get class predictions
y_pred_KNN_model = KNN_model.predict(X_val)

# Generate confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_val, y_pred_KNN_model))

# Classification report 
print("\nClassification Report:")
print(classification_report(y_val, y_pred_KNN_model))

# %% [markdown]
# #### Support Vector Machine (SVM)

# %%
# Initialize the model
svm = SVC(random_state=42)

# Fitting a model
svm.fit(X_train, y_train)

# Evaluate its classification accuracy
print(f'Train score: {svm.score(X_train, y_train)}')
print(f'Test score: {svm.score(X_val, y_val)}')

# Get class predictions
y_pred_svm = svm.predict(X_val)

# Generate confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_val, y_pred_svm))

# Classification report 
print("\nClassification Report:")
print(classification_report(y_val, y_pred_svm))

# %% [markdown]
# #### XGBoost

# %%
# Initialize the model
xgbc = XGBClassifier()

# Fitting a model
xgbc.fit(X_train, y_train)

# Evaluate its classification accuracy
print(f'Train score: {xgbc.score(X_train, y_train)}')
print(f'Test score: {xgbc.score(X_val, y_val)}')

# Get class predictions
y_pred_xgbc = xgbc.predict(X_val)

# Generate confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_val, y_pred_xgbc))

# Classification report 
print("\nClassification Report:")
print(classification_report(y_val, y_pred_xgbc))
